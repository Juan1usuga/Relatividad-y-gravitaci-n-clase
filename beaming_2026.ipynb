# %%
# En Python 3.14 en Windows, rebound suele fallar por compilación C++.
# %pip install -Uq pymcel montu
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for rebound (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [59 lines of output]
#       fatal: not a git repository (or any of the parent directories): .git
#       <string>:91: DeprecationWarning: codecs.open() is deprecated. Use open() instead.
#       C:\Users\Alejandro\AppData\Local\Temp\pip-build-env-mtdegr95\overlay\Lib\site-packages\setuptools\_distutils\dist.py:287: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       C:\Users\Alejandro\AppData\Local\Temp\pip-build-env-mtdegr95\overlay\Lib\site-packages\setuptools\_distutils\dist.py:287: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

import montu as mn 
import pymcel as pc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 import montu as mn
#       5 import pymcel as pc
#
# ModuleNotFoundError: No module named 'montu'
